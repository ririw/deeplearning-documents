# %%
# %pylab inline
pyplot.set_cmap('cubehelix')
pylab.rcParams['figure.figsize'] = (15.0, 10.0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img = imread('train_cleaned/101.png')

# %%
imshow((img < 1.0))
