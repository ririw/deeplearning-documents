# %%
# %pylab inline
pylab.rcParams['image.cmap'] = 'summer'
pylab.rcParams['figure.figsize'] = (15.0, 10.0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = 1-imread('train/101.png')
y = 1-imread('train_cleaned/101.png')

# %%
matshow(x)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y, x)**0.5
# Out:
# 0.17704840741088976

# %%
x[(y < 0.9)] = 0

# %%
matshow(x)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7fae1507d368>
